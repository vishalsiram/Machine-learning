# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Air data.csv')

# %%
df.shape
# Out:
# (1093, 9)

# %%
## Check for null values

sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df=df.dropna()

# %%
X=df.iloc[:,:-1] ## independent features
y=df.iloc[:,-1] ## dependent features

# %%
## check null values
X.isnull()
# Out:
#           T     TM     Tm    SLP      H     VV      V     VM
# 0     False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False
# 5     False  False  False  False  False  False  False  False
# 6     False  False  False  False  False  False  False  False
# 7     False  False  False  False  False  False  False  False
# 8     False  False  False  False  False  False  False  False
# 9     False  False  False  False  False  False  False  False
# 10    False  False  False  False  False  False  False  False
# 11    False  False  False  False  False  False  False  False
# 12    False  False  False  False  False  False  False  False
# 13    False  False  False  False  False  False  False  False
# 14    False  False  False  False  False  False  False  False
# 15    False  False  False  False  False  False  False  False
# 16    False  False  False  False  False  False  False  False
# 17    False  False  False  False  False  False  False  False
# 18    False  False  False  False  False  False  False  False
# 19    False  False  False  False  False  False  False  False
# 20    False  False  False  False  False  False  False  False
# 21    False  False  False  False  False  False  False  False
# 22    False  False  False  False  False  False  False  False
# 23    False  False  False  False  False  False  False  False
# 24    False  False  False  False  False  False  False  False
# 25    False  False  False  False  False  False  False  False
# 26    False  False  False  False  False  False  False  False
# 27    False  False  False  False  False  False  False  False
# 28    False  False  False  False  False  False  False  False
# 29    False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...
# 1063  False  False  False  False  False  False  False  False
# 1064  False  False  False  False  False  False  False  False
# 1065  False  False  False  False  False  False  False  False
# 1066  False  False  False  False  False  False  False  False
# 1067  False  False  False  False  False  False  False  False
# 1068  False  False  False  False  False  False  False  False
# 1069  False  False  False  False  False  False  False  False
# 1070  False  False  False  False  False  False  False  False
# 1071  False  False  False  False  False  False  False  False
# 1072  False  False  False  False  False  False  False  False
# 1073  False  False  False  False  False  False  False  False
# 1074  False  False  False  False  False  False  False  False
# 1075  False  False  False  False  False  False  False  False
# 1076  False  False  False  False  False  False  False  False
# 1077  False  False  False  False  False  False  False  False
# 1078  False  False  False  False  False  False  False  False
# 1079  False  False  False  False  False  False  False  False
# 1080  False  False  False  False  False  False  False  False
# 1081  False  False  False  False  False  False  False  False
# 1082  False  False  False  False  False  False  False  False
# 1083  False  False  False  False  False  False  False  False
# 1084  False  False  False  False  False  False  False  False
# 1085  False  False  False  False  False  False  False  False
# 1086  False  False  False  False  False  False  False  False
# 1087  False  False  False  False  False  False  False  False
# 1088  False  False  False  False  False  False  False  False
# 1089  False  False  False  False  False  False  False  False
# 1090  False  False  False  False  False  False  False  False
# 1091  False  False  False  False  False  False  False  False
# 1092  False  False  False  False  False  False  False  False
#
# [1092 rows x 8 columns]

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                T        TM        Tm       SLP         H        VV         V  \
# T       1.000000  0.967536  0.953719 -0.881409 -0.509299  0.640792  0.301994
# TM      0.967536  1.000000  0.892031 -0.822958 -0.586681  0.606945  0.292949
# Tm      0.953719  0.892031  1.000000 -0.917518 -0.287357  0.577240  0.296225
# SLP    -0.881409 -0.822958 -0.917518  1.000000  0.240256 -0.517915 -0.329838
# H      -0.509299 -0.586681 -0.287357  0.240256  1.000000 -0.465374 -0.380575
# VV      0.640792  0.606945  0.577240 -0.517915 -0.465374  1.000000  0.376873
# V       0.301994  0.292949  0.296225 -0.329838 -0.380575  0.376873  1.000000
# VM      0.287738  0.297011  0.266782 -0.310704 -0.362177  0.342442  0.775655
# PM 2.5 -0.631462 -0.568409 -0.673824  0.623187  0.138005 -0.573941 -0.268530
#
#               VM    PM 2.5
# T       0.287738 -0.631462
# TM      0.297011 -0.568409
# Tm      0.266782 -0.673824
# SLP    -0.310704  0.623187
# H      -0.362177  0.138005
# VV      0.342442 -0.573941
# V       0.775655 -0.268530
# VM      1.000000 -0.215854
# PM 2.5 -0.215854  1.000000

# %% [markdown]
# ## Correlation Matrix with Heatmap
#
# ### Correlation states how the features are related to each other or the target variable.
#
# ##### Correlation can be positive (increase in one value of feature increases the value of the target variable) or negative (increase in one value of feature decreases the value of the target variable)
#
# #####  Heatmap makes it easy to identify which features are most related to the target variable, we will plot heatmap of correlated features using the seaborn library.

# %%
import seaborn as sns
#get correlations of each features in dataset
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %% [markdown]
# ## Feature Importance
#
# You can get the feature importance of each feature of your dataset by using the feature importance property of the model.
#
# Feature importance gives you a score for each feature of your data, the higher the score more important or relevant is the feature towards your output variable.
#
# Feature importance is an inbuilt class that comes with Tree Based Regressor, we will be using Extra Tree Regressor for extracting the top 10 features for the dataset.

# %%
from sklearn.ensemble import ExtraTreesRegressor
import matplotlib.pyplot as plt
model = ExtraTreesRegressor()
model.fit(X,y)
# Out:
# C:\Users\vishal\AppData\Local\Continuum\anaconda3\envs\data_S\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ExtraTreesRegressor(bootstrap=False, criterion='mse', max_depth=None,
#                     max_features='auto', max_leaf_nodes=None,
#                     min_impurity_decrease=0.0, min_impurity_split=None,
#                     min_samples_leaf=1, min_samples_split=2,
#                     min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#                     oob_score=False, random_state=None, verbose=0,
#                     warm_start=False)

# %%
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.show()

# %% [markdown]
# # ANN

# %% [markdown]
# ## Train Test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout
# Out:
# Using TensorFlow backend.
# C:\Users\vishal\AppData\Local\Continuum\anaconda3\envs\data_S\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\vishal\AppData\Local\Continuum\anaconda3\envs\data_S\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\vishal\AppData\Local\Continuum\anaconda3\envs\data_S\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\vishal\AppData\Local\Continuum\anaconda3\envs\data_S\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\vishal\AppData\Local\Continuum\anaconda3\envs\data_S\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\vishal\AppData\Local\Continuum\anaconda3\envs\data_S\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()

# Fitting the ANN to the Training set
model_history=NN_model.fit(X_train, y_train,validation_split=0.33, batch_size = 10, nb_epoch = 100)
# Out:
# WARNING:tensorflow:From C:\Users\vishal\AppData\Local\Continuum\anaconda3\envs\data_S\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               1152
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 166,017
# Trainable params: 166,017
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From C:\Users\vishal\AppData\Local\Continuum\anaconda3\envs\data_S\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# C:\Users\vishal\AppData\Local\Continuum\anaconda3\envs\data_S\lib\site-packages\ipykernel_launcher.py:21: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 511 samples, validate on 253 samples
# Epoch 1/100
# 511/511 [==============================] - 0s 745us/step - loss: 69.0526 - mean_absolute_error: 69.0526 - val_loss: 65.4323 - val_mean_absolute_error: 65.4323
# Epoch 2/100
# 511/511 [==============================] - 0s 183us/step - loss: 68.2451 - mean_absolute_error: 68.2451 - val_loss: 66.4725 - val_mean_absolute_error: 66.4725
# Epoch 3/100
# 511/511 [==============================] - 0s 194us/step - loss: 64.3900 - mean_absolute_error: 64.3900 - val_loss: 66.8331 - val_mean_absolute_error: 66.8331
# Epoch 4/100
# 511/511 [==============================] - 0s 181us/step - loss: 60.8771 - mean_absolute_error: 60.8771 - val_loss: 56.3918 - val_mean_absolute_error: 56.3918
# Epoch 5/100
# 511/511 [==============================] - 0s 173us/step - loss: 55.2375 - mean_absolute_error: 55.2375 - val_loss: 52.1736 - val_mean_absolute_error: 52.1736
# Epoch 6/100
# 511/511 [==============================] - 0s 187us/step - loss: 50.5213 - mean_absolute_error: 50.5213 - val_loss: 47.1381 - val_mean_absolute_error: 47.1381
# Epoch 7/100
# 511/511 [==============================] - 0s 167us/step - loss: 44.7899 - mean_absolute_error: 44.7899 - val_loss: 48.8565 - val_mean_absolute_error: 48.8565
# Epoch 8/100
# 511/511 [==============================] - 0s 181us/step - loss: 44.2267 - mean_absolute_error: 44.2267 - val_loss: 45.8747 - val_mean_absolute_error: 45.8747
# Epoch 9/100
# 511/511 [==============================] - 0s 178us/step - loss: 46.3531 - mean_absolute_error: 46.3531 - val_loss: 48.4943 - val_mean_absolute_error: 48.4943
# Epoch 10/100
# 511/511 [==============================] - 0s 194us/step - loss: 43.9964 - mean_absolute_error: 43.9964 - val_loss: 48.4708 - val_mean_absolute_error: 48.4708
# Epoch 11/100
# 511/511 [==============================] - 0s 207us/step - loss: 43.3350 - mean_absolute_error: 43.3350 - val_loss: 52.5413 - val_mean_absolute_error: 52.5413
# Epoch 12/100
# 511/511 [==============================] - 0s 177us/step - loss: 44.4168 - mean_absolute_error: 44.4168 - val_loss: 44.4135 - val_mean_absolute_error: 44.4135
# Epoch 13/100
# 511/511 [==============================] - 0s 171us/step - loss: 42.5153 - mean_absolute_error: 42.5153 - val_loss: 44.3872 - val_mean_absolute_error: 44.3872
# Epoch 14/100
# 511/511 [==============================] - 0s 175us/step - loss: 42.5099 - mean_absolute_error: 42.5099 - val_loss: 44.3147 - val_mean_absolute_error: 44.3147
# Epoch 15/100
# 511/511 [==============================] - 0s 171us/step - loss: 42.7162 - mean_absolute_error: 42.7162 - val_loss: 44.6921 - val_mean_absolute_error: 44.6921
# Epoch 16/100
# 511/511 [==============================] - 0s 162us/step - loss: 43.2116 - mean_absolute_error: 43.2116 - val_loss: 45.8765 - val_mean_absolute_error: 45.8765
# Epoch 17/100
# 511/511 [==============================] - 0s 186us/step - loss: 42.0646 - mean_absolute_error: 42.0646 - val_loss: 46.9309 - val_mean_absolute_error: 46.9309
# Epoch 18/100
# 511/511 [==============================] - 0s 217us/step - loss: 41.7965 - mean_absolute_error: 41.7965 - val_loss: 45.6402 - val_mean_absolute_error: 45.6402
# Epoch 19/100
# 511/511 [==============================] - 0s 190us/step - loss: 44.1686 - mean_absolute_error: 44.1686 - val_loss: 45.9056 - val_mean_absolute_error: 45.9056
# Epoch 20/100
# 511/511 [==============================] - 0s 167us/step - loss: 42.9873 - mean_absolute_error: 42.9873 - val_loss: 46.4103 - val_mean_absolute_error: 46.4103
# Epoch 21/100
# 511/511 [==============================] - 0s 169us/step - loss: 41.4241 - mean_absolute_error: 41.4241 - val_loss: 46.4386 - val_mean_absolute_error: 46.4386
# Epoch 22/100
# 511/511 [==============================] - 0s 199us/step - loss: 43.4430 - mean_absolute_error: 43.4430 - val_loss: 44.3472 - val_mean_absolute_error: 44.3472
# Epoch 23/100
# 511/511 [==============================] - 0s 171us/step - loss: 41.5001 - mean_absolute_error: 41.5001 - val_loss: 45.7422 - val_mean_absolute_error: 45.7422
# Epoch 24/100
# 511/511 [==============================] - 0s 173us/step - loss: 42.0486 - mean_absolute_error: 42.0486 - val_loss: 45.0565 - val_mean_absolute_error: 45.0565
# Epoch 25/100
# 511/511 [==============================] - 0s 172us/step - loss: 44.3310 - mean_absolute_error: 44.3310 - val_loss: 48.2958 - val_mean_absolute_error: 48.2958
# Epoch 26/100
# 511/511 [==============================] - 0s 184us/step - loss: 41.0783 - mean_absolute_error: 41.0783 - val_loss: 46.4307 - val_mean_absolute_error: 46.4307
# Epoch 27/100
# 511/511 [==============================] - 0s 159us/step - loss: 42.2964 - mean_absolute_error: 42.2964 - val_loss: 44.1718 - val_mean_absolute_error: 44.1718
# Epoch 28/100
# 511/511 [==============================] - 0s 157us/step - loss: 41.6672 - mean_absolute_error: 41.6672 - val_loss: 44.4834 - val_mean_absolute_error: 44.4834
# Epoch 29/100
# 511/511 [==============================] - 0s 154us/step - loss: 47.2118 - mean_absolute_error: 47.2118 - val_loss: 45.7718 - val_mean_absolute_error: 45.7718
# Epoch 30/100
# 511/511 [==============================] - 0s 155us/step - loss: 41.1648 - mean_absolute_error: 41.1648 - val_loss: 44.2751 - val_mean_absolute_error: 44.2751
# Epoch 31/100
# 511/511 [==============================] - 0s 154us/step - loss: 41.4705 - mean_absolute_error: 41.4705 - val_loss: 44.1700 - val_mean_absolute_error: 44.1700
# Epoch 32/100
# 511/511 [==============================] - 0s 151us/step - loss: 41.0621 - mean_absolute_error: 41.0621 - val_loss: 43.8784 - val_mean_absolute_error: 43.8784
# Epoch 33/100
# 511/511 [==============================] - 0s 163us/step - loss: 40.8040 - mean_absolute_error: 40.8040 - val_loss: 45.0976 - val_mean_absolute_error: 45.0976
# Epoch 34/100
# 511/511 [==============================] - 0s 171us/step - loss: 40.4232 - mean_absolute_error: 40.4232 - val_loss: 47.2749 - val_mean_absolute_error: 47.2749
# Epoch 35/100
# 511/511 [==============================] - 0s 164us/step - loss: 41.9610 - mean_absolute_error: 41.9610 - val_loss: 44.5615 - val_mean_absolute_error: 44.5615
# Epoch 36/100
# 511/511 [==============================] - 0s 164us/step - loss: 40.9209 - mean_absolute_error: 40.9209 - val_loss: 48.4170 - val_mean_absolute_error: 48.4170
# Epoch 37/100
# 511/511 [==============================] - 0s 168us/step - loss: 42.1937 - mean_absolute_error: 42.1937 - val_loss: 47.3421 - val_mean_absolute_error: 47.3421
# Epoch 38/100
# 511/511 [==============================] - 0s 168us/step - loss: 41.5098 - mean_absolute_error: 41.5098 - val_loss: 48.0205 - val_mean_absolute_error: 48.0205
# Epoch 39/100
# 511/511 [==============================] - 0s 166us/step - loss: 43.3117 - mean_absolute_error: 43.3117 - val_loss: 57.7863 - val_mean_absolute_error: 57.7863
# Epoch 40/100
# 511/511 [==============================] - 0s 150us/step - loss: 43.8826 - mean_absolute_error: 43.8826 - val_loss: 44.7515 - val_mean_absolute_error: 44.7515
# Epoch 41/100
# 511/511 [==============================] - 0s 162us/step - loss: 40.5588 - mean_absolute_error: 40.5588 - val_loss: 44.8379 - val_mean_absolute_error: 44.8379
# Epoch 42/100
# 511/511 [==============================] - 0s 166us/step - loss: 41.8518 - mean_absolute_error: 41.8518 - val_loss: 45.5160 - val_mean_absolute_error: 45.5160
# Epoch 43/100
# 511/511 [==============================] - 0s 180us/step - loss: 40.1789 - mean_absolute_error: 40.1789 - val_loss: 48.4231 - val_mean_absolute_error: 48.4231
# Epoch 44/100
# 511/511 [==============================] - 0s 218us/step - loss: 40.4884 - mean_absolute_error: 40.4884 - val_loss: 44.1222 - val_mean_absolute_error: 44.1222
# Epoch 45/100
# 511/511 [==============================] - 0s 196us/step - loss: 40.0857 - mean_absolute_error: 40.0857 - val_loss: 43.7879 - val_mean_absolute_error: 43.7879
# Epoch 46/100
# 511/511 [==============================] - 0s 180us/step - loss: 40.3516 - mean_absolute_error: 40.3516 - val_loss: 44.6334 - val_mean_absolute_error: 44.6334
# Epoch 47/100
# 511/511 [==============================] - 0s 190us/step - loss: 42.2303 - mean_absolute_error: 42.2303 - val_loss: 47.1527 - val_mean_absolute_error: 47.1527
# Epoch 48/100
# 511/511 [==============================] - 0s 185us/step - loss: 41.8913 - mean_absolute_error: 41.8913 - val_loss: 49.0802 - val_mean_absolute_error: 49.0802
# Epoch 49/100
# 511/511 [==============================] - 0s 191us/step - loss: 42.3840 - mean_absolute_error: 42.3840 - val_loss: 45.1984 - val_mean_absolute_error: 45.1984
# Epoch 50/100
# 511/511 [==============================] - 0s 193us/step - loss: 42.6526 - mean_absolute_error: 42.6526 - val_loss: 48.7198 - val_mean_absolute_error: 48.7198
# Epoch 51/100
# 511/511 [==============================] - 0s 177us/step - loss: 40.6252 - mean_absolute_error: 40.6252 - val_loss: 45.0463 - val_mean_absolute_error: 45.0463
# Epoch 52/100
# 511/511 [==============================] - 0s 182us/step - loss: 40.4596 - mean_absolute_error: 40.4596 - val_loss: 44.3065 - val_mean_absolute_error: 44.3065
# Epoch 53/100
# 511/511 [==============================] - 0s 178us/step - loss: 39.6188 - mean_absolute_error: 39.6188 - val_loss: 43.9764 - val_mean_absolute_error: 43.9764
# Epoch 54/100
# 511/511 [==============================] - 0s 173us/step - loss: 40.2592 - mean_absolute_error: 40.2592 - val_loss: 45.0211 - val_mean_absolute_error: 45.0211
# Epoch 55/100
# 511/511 [==============================] - 0s 155us/step - loss: 39.8580 - mean_absolute_error: 39.8580 - val_loss: 44.1394 - val_mean_absolute_error: 44.1394
# Epoch 56/100
# 511/511 [==============================] - 0s 218us/step - loss: 39.7116 - mean_absolute_error: 39.7116 - val_loss: 43.6986 - val_mean_absolute_error: 43.6986
# Epoch 57/100
# 511/511 [==============================] - 0s 164us/step - loss: 40.4417 - mean_absolute_error: 40.4417 - val_loss: 43.7951 - val_mean_absolute_error: 43.7951
# Epoch 58/100
# 511/511 [==============================] - 0s 178us/step - loss: 39.4825 - mean_absolute_error: 39.4825 - val_loss: 43.4478 - val_mean_absolute_error: 43.4478
# Epoch 59/100
# 511/511 [==============================] - 0s 173us/step - loss: 40.5455 - mean_absolute_error: 40.5455 - val_loss: 43.5083 - val_mean_absolute_error: 43.5083
# Epoch 60/100
# 511/511 [==============================] - 0s 162us/step - loss: 39.0858 - mean_absolute_error: 39.0858 - val_loss: 43.7534 - val_mean_absolute_error: 43.7534
# Epoch 61/100
# 511/511 [==============================] - 0s 167us/step - loss: 41.3166 - mean_absolute_error: 41.3166 - val_loss: 44.9651 - val_mean_absolute_error: 44.9651
# Epoch 62/100
# 511/511 [==============================] - 0s 163us/step - loss: 40.4989 - mean_absolute_error: 40.4989 - val_loss: 46.5398 - val_mean_absolute_error: 46.5398
# Epoch 63/100
# 511/511 [==============================] - 0s 153us/step - loss: 40.0804 - mean_absolute_error: 40.0804 - val_loss: 47.8001 - val_mean_absolute_error: 47.8001
# Epoch 64/100
# 511/511 [==============================] - 0s 154us/step - loss: 40.7259 - mean_absolute_error: 40.7259 - val_loss: 44.3914 - val_mean_absolute_error: 44.3914
# Epoch 65/100
# 511/511 [==============================] - 0s 172us/step - loss: 41.6203 - mean_absolute_error: 41.6203 - val_loss: 43.6770 - val_mean_absolute_error: 43.6770
# Epoch 66/100
# 511/511 [==============================] - 0s 172us/step - loss: 40.2797 - mean_absolute_error: 40.2797 - val_loss: 44.5161 - val_mean_absolute_error: 44.5161
# Epoch 67/100
# 511/511 [==============================] - 0s 173us/step - loss: 41.6525 - mean_absolute_error: 41.6525 - val_loss: 44.0467 - val_mean_absolute_error: 44.0467
# Epoch 68/100
# 511/511 [==============================] - 0s 171us/step - loss: 40.1299 - mean_absolute_error: 40.1299 - val_loss: 43.6453 - val_mean_absolute_error: 43.6453
# Epoch 69/100
# 511/511 [==============================] - 0s 167us/step - loss: 40.1689 - mean_absolute_error: 40.1689 - val_loss: 48.9910 - val_mean_absolute_error: 48.9910
# Epoch 70/100
# 511/511 [==============================] - 0s 178us/step - loss: 40.0561 - mean_absolute_error: 40.0561 - val_loss: 45.0338 - val_mean_absolute_error: 45.0338
# Epoch 71/100
# 511/511 [==============================] - 0s 172us/step - loss: 43.1004 - mean_absolute_error: 43.1004 - val_loss: 47.1011 - val_mean_absolute_error: 47.1011
# Epoch 72/100
# 511/511 [==============================] - 0s 154us/step - loss: 41.8129 - mean_absolute_error: 41.8129 - val_loss: 43.3233 - val_mean_absolute_error: 43.3233
# Epoch 73/100
# 511/511 [==============================] - 0s 158us/step - loss: 40.3710 - mean_absolute_error: 40.3710 - val_loss: 48.5837 - val_mean_absolute_error: 48.5837
# Epoch 74/100
# 511/511 [==============================] - 0s 158us/step - loss: 40.3629 - mean_absolute_error: 40.3629 - val_loss: 43.9405 - val_mean_absolute_error: 43.9405
# Epoch 75/100
# 511/511 [==============================] - 0s 173us/step - loss: 42.1700 - mean_absolute_error: 42.1700 - val_loss: 43.5031 - val_mean_absolute_error: 43.5031
# Epoch 76/100
# 511/511 [==============================] - 0s 158us/step - loss: 39.5139 - mean_absolute_error: 39.5139 - val_loss: 43.3171 - val_mean_absolute_error: 43.3171
# Epoch 77/100
# 511/511 [==============================] - 0s 171us/step - loss: 40.7121 - mean_absolute_error: 40.7121 - val_loss: 43.6923 - val_mean_absolute_error: 43.6923
# Epoch 78/100
# 511/511 [==============================] - 0s 325us/step - loss: 39.0071 - mean_absolute_error: 39.0071 - val_loss: 49.4770 - val_mean_absolute_error: 49.4770
# Epoch 79/100
# 511/511 [==============================] - 0s 293us/step - loss: 39.8917 - mean_absolute_error: 39.8917 - val_loss: 44.5545 - val_mean_absolute_error: 44.5545
# Epoch 80/100
# 511/511 [==============================] - 0s 162us/step - loss: 39.6425 - mean_absolute_error: 39.6425 - val_loss: 47.6760 - val_mean_absolute_error: 47.6760
# Epoch 81/100
# 511/511 [==============================] - 0s 160us/step - loss: 39.8582 - mean_absolute_error: 39.8582 - val_loss: 43.9361 - val_mean_absolute_error: 43.9361
# Epoch 82/100
# 511/511 [==============================] - 0s 159us/step - loss: 40.5839 - mean_absolute_error: 40.5839 - val_loss: 43.3901 - val_mean_absolute_error: 43.3901
# Epoch 83/100
# 511/511 [==============================] - 0s 168us/step - loss: 42.4367 - mean_absolute_error: 42.4367 - val_loss: 43.6259 - val_mean_absolute_error: 43.6259
# Epoch 84/100
# 511/511 [==============================] - 0s 163us/step - loss: 40.0531 - mean_absolute_error: 40.0531 - val_loss: 43.3897 - val_mean_absolute_error: 43.3897
# Epoch 85/100
# 511/511 [==============================] - 0s 171us/step - loss: 39.3214 - mean_absolute_error: 39.3214 - val_loss: 44.8722 - val_mean_absolute_error: 44.8722
# Epoch 86/100
# 511/511 [==============================] - 0s 252us/step - loss: 40.5764 - mean_absolute_error: 40.5764 - val_loss: 43.7973 - val_mean_absolute_error: 43.7973
# Epoch 87/100
# 511/511 [==============================] - 0s 335us/step - loss: 39.7906 - mean_absolute_error: 39.7906 - val_loss: 43.2158 - val_mean_absolute_error: 43.2158
# Epoch 88/100
# 511/511 [==============================] - 0s 308us/step - loss: 38.6830 - mean_absolute_error: 38.6830 - val_loss: 44.7071 - val_mean_absolute_error: 44.7071
# Epoch 89/100
# 511/511 [==============================] - 0s 311us/step - loss: 40.1260 - mean_absolute_error: 40.1260 - val_loss: 44.7516 - val_mean_absolute_error: 44.7516
# Epoch 90/100
# 511/511 [==============================] - 0s 267us/step - loss: 39.2316 - mean_absolute_error: 39.2316 - val_loss: 46.4135 - val_mean_absolute_error: 46.4135
# Epoch 91/100
# 511/511 [==============================] - 0s 348us/step - loss: 39.2287 - mean_absolute_error: 39.2287 - val_loss: 43.3539 - val_mean_absolute_error: 43.3539
# Epoch 92/100
# 511/511 [==============================] - 0s 218us/step - loss: 40.3529 - mean_absolute_error: 40.3529 - val_loss: 46.5712 - val_mean_absolute_error: 46.5712
# Epoch 93/100
# 511/511 [==============================] - 0s 371us/step - loss: 40.5341 - mean_absolute_error: 40.5341 - val_loss: 43.7110 - val_mean_absolute_error: 43.7110
# Epoch 94/100
# 511/511 [==============================] - 0s 212us/step - loss: 39.3423 - mean_absolute_error: 39.3423 - val_loss: 43.8274 - val_mean_absolute_error: 43.8274
# Epoch 95/100
# 511/511 [==============================] - 0s 324us/step - loss: 39.9265 - mean_absolute_error: 39.9265 - val_loss: 44.2014 - val_mean_absolute_error: 44.2014
# Epoch 96/100
# 511/511 [==============================] - 0s 196us/step - loss: 38.9454 - mean_absolute_error: 38.9454 - val_loss: 46.0302 - val_mean_absolute_error: 46.0302
# Epoch 97/100
# 511/511 [==============================] - 0s 191us/step - loss: 39.3673 - mean_absolute_error: 39.3673 - val_loss: 44.9794 - val_mean_absolute_error: 44.9794
# Epoch 98/100
# 511/511 [==============================] - 0s 199us/step - loss: 38.7169 - mean_absolute_error: 38.7169 - val_loss: 43.2590 - val_mean_absolute_error: 43.2590
# Epoch 99/100
# 511/511 [==============================] - 0s 202us/step - loss: 39.7339 - mean_absolute_error: 39.7339 - val_loss: 50.2853 - val_mean_absolute_error: 50.2853
# Epoch 100/100
# 511/511 [==============================] - 0s 209us/step - loss: 39.4174 - mean_absolute_error: 39.4174 - val_loss: 43.0830 - val_mean_absolute_error: 43.0830

# %% [markdown]
# # Prediction

# %%
prediction=NN_model.predict(X_test)
plt.scatter(y_test,prediction)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 42.360461370731755
# MSE: 3879.527709370058
# RMSE: 62.285854809660094
